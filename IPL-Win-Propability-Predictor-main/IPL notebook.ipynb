# %%
import numpy as np
import pandas as pd

# %%
matches = pd.read_csv("matches.csv")
deliveries = pd.read_csv("deliveries.csv")

# %%
matches.head()
# Out:
#    id    Season       city  ...         umpire1        umpire2 umpire3
# 0   1  IPL-2017  Hyderabad  ...     AY Dandekar       NJ Llong     NaN
# 1   2  IPL-2017       Pune  ...  A Nand Kishore         S Ravi     NaN
# 2   3  IPL-2017     Rajkot  ...     Nitin Menon      CK Nandan     NaN
# 3   4  IPL-2017     Indore  ...    AK Chaudhary  C Shamshuddin     NaN
# 4   5  IPL-2017  Bangalore  ...             NaN            NaN     NaN
#
# [5 rows x 18 columns]

# %%
deliveries.head(10)
# Out:
#    match_id  inning         batting_team  ... player_dismissed  dismissal_kind  fielder
# 0         1       1  Sunrisers Hyderabad  ...              NaN             NaN      NaN
# 1         1       1  Sunrisers Hyderabad  ...              NaN             NaN      NaN
# 2         1       1  Sunrisers Hyderabad  ...              NaN             NaN      NaN
# 3         1       1  Sunrisers Hyderabad  ...              NaN             NaN      NaN
# 4         1       1  Sunrisers Hyderabad  ...              NaN             NaN      NaN
# 5         1       1  Sunrisers Hyderabad  ...              NaN             NaN      NaN
# 6         1       1  Sunrisers Hyderabad  ...              NaN             NaN      NaN
# 7         1       1  Sunrisers Hyderabad  ...              NaN             NaN      NaN
# 8         1       1  Sunrisers Hyderabad  ...              NaN             NaN      NaN
# 9         1       1  Sunrisers Hyderabad  ...              NaN             NaN      NaN
#
# ...

# %%
total_socre_df = deliveries.groupby(['match_id', 'inning']).sum()['total_runs'].reset_index()

# %%
total_socre_df = total_socre_df[total_socre_df['inning']==1]

# %%
total_socre_df
# Out:
#       match_id  inning  total_runs
# 0            1       1         207
# 2            2       1         184
# 4            3       1         183
# 6            4       1         163
# 8            5       1         157
# ...        ...     ...         ...
# 1518     11347       1         143
# 1520     11412       1         136
# 1522     11413       1         171
# 1524     11414       1         155
# 1526     11415       1         152
#
# [756 rows x 3 columns]

# %%
match_df = matches.merge(total_socre_df[['match_id', 'total_runs']], left_on='id', right_on='match_id')

# %%
match_df
# Out:
#         id    Season           city        date  ...         umpire2                  umpire3 match_id total_runs
# 0        1  IPL-2017      Hyderabad  05-04-2017  ...        NJ Llong                      NaN        1        207
# 1        2  IPL-2017           Pune  06-04-2017  ...          S Ravi                      NaN        2        184
# 2        3  IPL-2017         Rajkot  07-04-2017  ...       CK Nandan                      NaN        3        183
# 3        4  IPL-2017         Indore  08-04-2017  ...   C Shamshuddin                      NaN        4        163
# 4        5  IPL-2017      Bangalore  08-04-2017  ...             NaN                      NaN        5        157
# ..     ...       ...            ...         ...  ...             ...                      ...      ...        ...
# 751  11347  IPL-2019         Mumbai  05-05-2019  ...        O Nandan                   S Ravi    11347        143
# ...

# %%
match_df['team1'].unique()
# Out:
# array(['Sunrisers Hyderabad', 'Mumbai Indians', 'Gujarat Lions',
#        'Rising Pune Supergiant', 'Royal Challengers Bangalore',
#        'Kolkata Knight Riders', 'Delhi Daredevils', 'Kings XI Punjab',
#        'Chennai Super Kings', 'Rajasthan Royals', 'Deccan Chargers',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Rising Pune Supergiants',
#        'Delhi Capitals'], dtype=object)

# %%
teams = [
    'Sunrisers Hyderabad',
    'Mumbai Indians',
    'Royal Challengers Bangalore',
    'Kolkata Knight Riders',
    'Kings XI Punjab',
    'Chennai Super Kings',
    'Rajasthan Royals',
    'Delhi Capitals'
]

# %%
match_df['team1']= match_df['team1'].str.replace('Delhi Daredevils', 'Delhi Capitals')
match_df['team1']= match_df['team1'].str.replace('Deccan Chargers', 'Sunrisers Hyderabad')

match_df['team2']= match_df['team2'].str.replace('Delhi Daredevils', 'Delhi Capitals')
match_df['team2']= match_df['team2'].str.replace('Deccan Chargers', 'Sunrisers Hyderabad')

# %%
match_df = match_df[match_df['team1'].isin(teams)]
match_df = match_df[match_df['team2'].isin(teams)]

# %%
match_df
# Out:
#         id    Season           city        date  ...         umpire2                  umpire3 match_id total_runs
# 0        1  IPL-2017      Hyderabad  05-04-2017  ...        NJ Llong                      NaN        1        207
# 4        5  IPL-2017      Bangalore  08-04-2017  ...             NaN                      NaN        5        157
# 6        7  IPL-2017         Mumbai  09-04-2017  ...       CK Nandan                      NaN        7        178
# 7        8  IPL-2017         Indore  10-04-2017  ...   C Shamshuddin                      NaN        8        148
# 9       10  IPL-2017         Mumbai  12-04-2017  ...       CK Nandan                      NaN       10        158
# ..     ...       ...            ...         ...  ...             ...                      ...      ...        ...
# 751  11347  IPL-2019         Mumbai  05-05-2019  ...        O Nandan                   S Ravi    11347        143
# ...

# %%
match_df['dl_applied'].value_counts()
# Out:
# 0    626
# 1     15
# Name: dl_applied, dtype: int64

# %%
match_df = match_df[match_df.dl_applied==0]

# %%
match_df.shape
# Out:
# (626, 20)

# %%
match_df = match_df[['match_id', 'city', 'winner', 'total_runs']]

# %%
delivery_df = match_df.merge(deliveries, on='match_id')

# %%
delivery_df
# Out:
#         match_id       city               winner  total_runs_x  ...  total_runs_y player_dismissed dismissal_kind    fielder
# 0              1  Hyderabad  Sunrisers Hyderabad           207  ...             0              NaN            NaN        NaN
# 1              1  Hyderabad  Sunrisers Hyderabad           207  ...             0              NaN            NaN        NaN
# 2              1  Hyderabad  Sunrisers Hyderabad           207  ...             4              NaN            NaN        NaN
# 3              1  Hyderabad  Sunrisers Hyderabad           207  ...             0              NaN            NaN        NaN
# 4              1  Hyderabad  Sunrisers Hyderabad           207  ...             2              NaN            NaN        NaN
# ...          ...        ...                  ...           ...  ...           ...              ...            ...        ...
# ...

# %%
delivery_df = delivery_df[delivery_df.inning==2]

# %%
delivery_df
# Out:
#         match_id       city               winner  total_runs_x  ...  total_runs_y player_dismissed dismissal_kind    fielder
# 125            1  Hyderabad  Sunrisers Hyderabad           207  ...             1              NaN            NaN        NaN
# 126            1  Hyderabad  Sunrisers Hyderabad           207  ...             0              NaN            NaN        NaN
# 127            1  Hyderabad  Sunrisers Hyderabad           207  ...             0              NaN            NaN        NaN
# 128            1  Hyderabad  Sunrisers Hyderabad           207  ...             2              NaN            NaN        NaN
# 129            1  Hyderabad  Sunrisers Hyderabad           207  ...             4              NaN            NaN        NaN
# ...          ...        ...                  ...           ...  ...           ...              ...            ...        ...
# ...

# %%
delivery_df['curr_score'] = delivery_df.groupby('match_id').cumsum()['total_runs_y']
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_7224\1911434206.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['curr_score'] = delivery_df.groupby('match_id').cumsum()['total_runs_y']

# %%
delivery_df.curr_score
# Out:
# 125         1
# 126         1
# 127         1
# 128         3
# 129         7
#          ...
# 149573    152
# 149574    154
# 149575    155
# 149576    157
# 149577    157
# Name: curr_score, Length: 72413, dtype: int64

# %%
delivery_df['runs_left'] = delivery_df['total_runs_x'] - delivery_df['curr_score']
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_7224\3621542204.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['runs_left'] = delivery_df['total_runs_x'] - delivery_df['curr_score']

# %%
delivery_df.runs_left
# Out:
# 125       206
# 126       206
# 127       206
# 128       204
# 129       200
#          ...
# 149573      0
# 149574     -2
# 149575     -3
# 149576     -5
# 149577     -5
# Name: runs_left, Length: 72413, dtype: int64

# %%
delivery_df['ball_left'] = 120- ((delivery_df['over']-1) *6) - (delivery_df['ball'])
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_7224\4033257582.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['ball_left'] = 120- ((delivery_df['over']-1) *6) - (delivery_df['ball'])

# %%
delivery_df
# Out:
#         match_id       city               winner  total_runs_x  ...    fielder curr_score runs_left  ball_left
# 125            1  Hyderabad  Sunrisers Hyderabad           207  ...        NaN          1       206        119
# 126            1  Hyderabad  Sunrisers Hyderabad           207  ...        NaN          1       206        118
# 127            1  Hyderabad  Sunrisers Hyderabad           207  ...        NaN          1       206        117
# 128            1  Hyderabad  Sunrisers Hyderabad           207  ...        NaN          3       204        116
# 129            1  Hyderabad  Sunrisers Hyderabad           207  ...        NaN          7       200        115
# ...          ...        ...                  ...           ...  ...        ...        ...       ...        ...
# 149573     11415  Hyderabad       Mumbai Indians           152  ...        NaN        152         0          4
# ...

# %%
delivery_df['player_dismissed'] = delivery_df['player_dismissed'].fillna("0")
delivery_df['player_dismissed'] = delivery_df['player_dismissed'].apply(lambda x:x if x == "0" else "1")
delivery_df['player_dismissed'] = delivery_df['player_dismissed'].astype('int')
wickets = delivery_df.groupby('match_id').cumsum()['player_dismissed'].values
delivery_df['wickets'] = 10 - wickets
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_7224\2108117603.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['player_dismissed'] = delivery_df['player_dismissed'].fillna("0")
# C:\Users\HP\AppData\Local\Temp\ipykernel_7224\2108117603.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['player_dismissed'] = delivery_df['player_dismissed'].apply(lambda x:x if x == "0" else "1")
# C:\Users\HP\AppData\Local\Temp\ipykernel_7224\2108117603.py:3: SettingWithCopyWarning:
# ...

# %%
delivery_df.player_dismissed
# Out:
# 125       0
# 126       0
# 127       0
# 128       0
# 129       0
#          ..
# 149573    0
# 149574    0
# 149575    1
# 149576    0
# 149577    1
# Name: player_dismissed, Length: 72413, dtype: int32

# %%
delivery_df.player_dismissed.value_counts()
# Out:
# 0    68860
# 1     3553
# Name: player_dismissed, dtype: int64

# %%
delivery_df
# Out:
#         match_id       city               winner  total_runs_x  ...  curr_score runs_left ball_left  wickets
# 125            1  Hyderabad  Sunrisers Hyderabad           207  ...           1       206       119       10
# 126            1  Hyderabad  Sunrisers Hyderabad           207  ...           1       206       118       10
# 127            1  Hyderabad  Sunrisers Hyderabad           207  ...           1       206       117       10
# 128            1  Hyderabad  Sunrisers Hyderabad           207  ...           3       204       116       10
# 129            1  Hyderabad  Sunrisers Hyderabad           207  ...           7       200       115       10
# ...          ...        ...                  ...           ...  ...         ...       ...       ...      ...
# 149573     11415  Hyderabad       Mumbai Indians           152  ...         152         0         4        5
# 149574     11415  Hyderabad       Mumbai Indians           152  ...         154        -2         3        5
# ...

# %%
delivery_df['curr_rr'] = delivery_df['curr_score']/((120 - delivery_df['ball_left'])/6)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_7224\3811119609.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['curr_rr'] = delivery_df['curr_score']/((120 - delivery_df['ball_left'])/6)

# %%
delivery_df
# Out:
#         match_id       city               winner  total_runs_x  ...  runs_left ball_left wickets   curr_rr
# 125            1  Hyderabad  Sunrisers Hyderabad           207  ...        206       119      10  6.000000
# 126            1  Hyderabad  Sunrisers Hyderabad           207  ...        206       118      10  3.000000
# 127            1  Hyderabad  Sunrisers Hyderabad           207  ...        206       117      10  2.000000
# 128            1  Hyderabad  Sunrisers Hyderabad           207  ...        204       116      10  4.500000
# 129            1  Hyderabad  Sunrisers Hyderabad           207  ...        200       115      10  8.400000
# ...          ...        ...                  ...           ...  ...        ...       ...     ...       ...
# 149573     11415  Hyderabad       Mumbai Indians           152  ...          0         4       5  7.862069
# 149574     11415  Hyderabad       Mumbai Indians           152  ...         -2         3       5  7.897436
# ...

# %%
delivery_df['req_rr'] = (delivery_df['runs_left'] * 6)/ delivery_df['ball_left']
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_7224\2644468505.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['req_rr'] = (delivery_df['runs_left'] * 6)/ delivery_df['ball_left']

# %%
delivery_df
# Out:
#         match_id       city               winner  total_runs_x  ...  ball_left wickets   curr_rr     req_rr
# 125            1  Hyderabad  Sunrisers Hyderabad           207  ...        119      10  6.000000  10.386555
# 126            1  Hyderabad  Sunrisers Hyderabad           207  ...        118      10  3.000000  10.474576
# 127            1  Hyderabad  Sunrisers Hyderabad           207  ...        117      10  2.000000  10.564103
# 128            1  Hyderabad  Sunrisers Hyderabad           207  ...        116      10  4.500000  10.551724
# 129            1  Hyderabad  Sunrisers Hyderabad           207  ...        115      10  8.400000  10.434783
# ...          ...        ...                  ...           ...  ...        ...     ...       ...        ...
# 149573     11415  Hyderabad       Mumbai Indians           152  ...          4       5  7.862069   0.000000
# 149574     11415  Hyderabad       Mumbai Indians           152  ...          3       5  7.897436  -4.000000
# ...

# %%
def result(row):
    return 1 if row['batting_team'] == row['winner'] else 0

# %%
delivery_df['result'] = delivery_df.apply(result, axis=1)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_7224\343102418.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['result'] = delivery_df.apply(result, axis=1)

# %%
delivery_df.tail()
# Out:
#         match_id       city          winner  total_runs_x  inning  ... ball_left wickets   curr_rr  req_rr result
# 149573     11415  Hyderabad  Mumbai Indians           152       2  ...         4       5  7.862069     0.0      0
# 149574     11415  Hyderabad  Mumbai Indians           152       2  ...         3       5  7.897436    -4.0      0
# 149575     11415  Hyderabad  Mumbai Indians           152       2  ...         2       4  7.881356    -9.0      0
# 149576     11415  Hyderabad  Mumbai Indians           152       2  ...         1       4  7.915966   -30.0      0
# 149577     11415  Hyderabad  Mumbai Indians           152       2  ...         0       3  7.850000    -inf      0
#
# [5 rows x 31 columns]

# %%
final_df = delivery_df[['batting_team', 'bowling_team','city', 'runs_left', 'ball_left', 'wickets', 'curr_rr', 'req_rr', 'result' ]]

# %%
final_df
# Out:
#                        batting_team         bowling_team       city  runs_left  ...  wickets   curr_rr     req_rr  result
# 125     Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad        206  ...       10  6.000000  10.386555       0
# 126     Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad        206  ...       10  3.000000  10.474576       0
# 127     Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad        206  ...       10  2.000000  10.564103       0
# 128     Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad        204  ...       10  4.500000  10.551724       0
# 129     Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad        200  ...       10  8.400000  10.434783       0
# ...                             ...                  ...        ...        ...  ...      ...       ...        ...     ...
# 149573          Chennai Super Kings       Mumbai Indians  Hyderabad          0  ...        5  7.862069   0.000000       0
# ...

# %%
final_df = final_df.sample(final_df.shape[0])

# %%
final_df
# Out:
#                        batting_team                 bowling_team           city  ...    curr_rr     req_rr  result
# 85157                Mumbai Indians              Kings XI Punjab     Dharamsala  ...   2.000000   9.526316       0
# 73449           Sunrisers Hyderabad  Royal Challengers Bangalore      Hyderabad  ...   5.531250   7.607143       1
# 86243                Mumbai Indians             Rajasthan Royals        Kolkata  ...   7.500000   8.522727       1
# 59869                Mumbai Indians              Deccan Chargers  Visakhapatnam  ...   3.200000   7.428571       1
# 79985           Sunrisers Hyderabad               Mumbai Indians      Hyderabad  ...   6.226415   6.626866       1
# ...                             ...                          ...            ...  ...        ...        ...     ...
# 93010   Royal Challengers Bangalore               Mumbai Indians         Mumbai  ...   8.603774  15.000000       0
# ...

# %%
final_df.isnull().sum()
# Out:
# batting_team      0
# bowling_team      0
# city            832
# runs_left         0
# ball_left         0
# wickets           0
# curr_rr           0
# req_rr            7
# result            0
# dtype: int64

# %%
final_df.dropna(inplace=True)

# %%
final_df = final_df[final_df['ball_left']!=0]

# %%
final_df.sample()
# Out:
#                  batting_team                 bowling_team     city  runs_left  ...  wickets    curr_rr    req_rr  result
# 122153  Kolkata Knight Riders  Royal Challengers Bangalore  Kolkata         79  ...        7  10.474576  7.770492       1
#
# [1 rows x 9 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X = final_df.iloc[:, :-1]
y = final_df['result']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
X_train
# Out:
#                        batting_team                 bowling_team       city  ...  wickets   curr_rr     req_rr
# 50177   Royal Challengers Bangalore          Chennai Super Kings    Chennai  ...        6  7.259259  13.076923
# 33545               Deccan Chargers        Kolkata Knight Riders     Mumbai  ...        6  8.133333   7.800000
# 64017              Rajasthan Royals  Royal Challengers Bangalore     Jaipur  ...        5  7.140000  21.000000
# 42791              Delhi Daredevils        Kolkata Knight Riders    Kolkata  ...        5  8.673267  11.052632
# 24946               Kings XI Punjab  Royal Challengers Bangalore     Durban  ...       10  3.600000   7.408696
# ...                             ...                          ...        ...  ...      ...       ...        ...
# 109645               Mumbai Indians             Delhi Daredevils     Mumbai  ...        7  6.206897   8.043956
# ...

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
trf = ColumnTransformer([
    ('trf', OneHotEncoder(sparse='False', drop= 'first'), ['batting_team', 'bowling_team', 'city'] )
],
remainder='passthrough')

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline

# %%
pipe_logistic_regression = Pipeline(steps=[
    ('step1', trf),
    ('step2', LogisticRegression(solver='liblinear'))
])

# %%
pipe_Random_forest = Pipeline(steps=[
    ('step1', trf),
    ('step2', RandomForestClassifier())
])

# %%
pipe_logistic_regression.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse='False'),
#                                                   ['batting_team',
#                                                    'bowling_team', 'city'])])),
#                 ('step2', LogisticRegression(solver='liblinear'))])

# %%
y_pred_logistic = pipe_logistic_regression.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred_logistic)
# Out:
# 0.796832293783727

# %%
pipe_Random_forest.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse='False'),
#                                                   ['batting_team',
#                                                    'bowling_team', 'city'])])),
#                 ('step2', RandomForestClassifier())])

# %%
y_pred_Random = pipe_Random_forest.predict(X_test)

# %%
accuracy_score(y_test, y_pred_Random)
# Out:
# 0.996005326231691

# %%
pipe_logistic_regression.predict_proba(X_test)[10]
# Out:
# array([0.96222595, 0.03777405])

# %%
pipe_Random_forest.predict_proba(X_test)[10]
# Out:
# array([1., 0.])

# %%
def match_progression(x_df,match_id,pipe_logistic_regression):
    match = x_df[x_df['match_id'] == match_id]
    match = match[(match['ball'] == 6)]
    temp_df = match[['batting_team','bowling_team','city','runs_left','ball_left','wickets','total_runs_x','curr_rr','req_rr']].dropna()
    temp_df = temp_df[temp_df['ball_left'] != 0]
    result = pipe_logistic_regression.predict_proba(temp_df)
    temp_df['lose'] = np.round(result.T[0]*100,1)
    temp_df['win'] = np.round(result.T[1]*100,1)
    temp_df['end_of_over'] = range(1,temp_df.shape[0]+1)
    
    target = temp_df['total_runs_x'].values[0]
    runs = list(temp_df['runs_left'].values)
    new_runs = runs[:]
    runs.insert(0,target)
    temp_df['runs_after_over'] = np.array(runs)[:-1] - np.array(new_runs)
    wickets = list(temp_df['wickets'].values)
    new_wickets = wickets[:]
    new_wickets.insert(0,10)
    wickets.append(0)
    w = np.array(wickets)
    nw = np.array(new_wickets)
    temp_df['wickets_in_over'] = (nw - w)[0:temp_df.shape[0]]
    
    print("Target-",target)
    temp_df = temp_df[['end_of_over','runs_after_over','wickets_in_over','lose','win']]
    return temp_df,target

# %%
temp_df,target = match_progression(delivery_df,74,pipe_logistic_regression)
temp_df
# Out:
# Target- 178
#        end_of_over  runs_after_over  wickets_in_over  lose   win
# 10459            1                4                0  55.9  44.1
# 10467            2                8                0  50.2  49.8
# 10473            3                1                0  57.0  43.0
# 10479            4                7                1  68.7  31.3
# 10485            5               12                0  58.3  41.7
# 10491            6               13                0  45.9  54.1
# 10497            7                9                0  40.0  60.0
# 10505            8               15                0  26.4  73.6
# 10511            9                7                0  24.2  75.8
# 10518           10               17                0  13.2  86.8
# 10524           11                9                1  18.5  81.5
# 10530           12                9                0  15.1  84.9
# 10536           13                8                0  13.0  87.0
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(18,8))
plt.plot(temp_df['end_of_over'],temp_df['wickets_in_over'],color='yellow',linewidth=3)
plt.plot(temp_df['end_of_over'],temp_df['win'],color='#00a65a',linewidth=4)
plt.plot(temp_df['end_of_over'],temp_df['lose'],color='red',linewidth=4)
plt.bar(temp_df['end_of_over'],temp_df['runs_after_over'])
plt.title('Target-' + str(target))
# Out:
# Text(0.5, 1.0, 'Target-178')

# %%
teams
# Out:
# ['Sunrisers Hyderabad',
#  'Mumbai Indians',
#  'Royal Challengers Bangalore',
#  'Kolkata Knight Riders',
#  'Kings XI Punjab',
#  'Chennai Super Kings',
#  'Rajasthan Royals',
#  'Delhi Capitals']

# %%
delivery_df['city'].unique()
# Out:
# array(['Hyderabad', 'Bangalore', 'Mumbai', 'Indore', 'Kolkata', 'Delhi',
#        'Chandigarh', 'Jaipur', 'Chennai', 'Cape Town', 'Port Elizabeth',
#        'Durban', 'Centurion', 'East London', 'Johannesburg', 'Kimberley',
#        'Bloemfontein', 'Ahmedabad', 'Cuttack', 'Nagpur', 'Dharamsala',
#        'Visakhapatnam', 'Pune', 'Raipur', 'Ranchi', 'Abu Dhabi',
#        'Sharjah', nan, 'Mohali', 'Bengaluru'], dtype=object)

# %%
import pickle
pickle.dump(pipe_logistic_regression, open('pickle.pkl', 'wb'))

# %%
# !pip install pandas-profiling

# %%
from pandas_profiling import ProfileReport
prof = ProfileReport(delivery_df)
prof.to_file(output_file='report.html')
# Out:
# C:\Users\HP\anaconda\lib\site-packages\multimethod\__init__.py:315: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# C:\Users\HP\anaconda\lib\site-packages\numpy\core\_methods.py:48: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# C:\Users\HP\anaconda\lib\site-packages\numpy\core\_methods.py:212: RuntimeWarning: invalid value encountered in reduce
#   arrmean = umr_sum(arr, axis, dtype, keepdims=True, where=where)
# C:\Users\HP\anaconda\lib\site-packages\pandas_profiling\model\correlations.py:67: UserWarning: There was an attempt to calculate the auto correlation, but this failed.
# To hide this warning, disable the calculation
# ...
